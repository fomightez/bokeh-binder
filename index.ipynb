# %% [markdown]
# # Bokeh examples work in this binder
#
# environment.yml contents in that repo where Bokeh gallery plots worked:
#
# ```
# channels:
#   - conda-forge
#   - anaconda-fusion
#   - defaults
# dependencies:
#   - python
#   - numpy
#   - pandas
#   - bokeh
# ```

# %%
import pandas as pd
import numpy as np
from datetime import date

# %%
from bokeh.plotting import figure
from bokeh.layouts import layout, widgetbox, column
from bokeh.io import output_notebook, show
from bokeh.models import Slider,Label,LabelSet,WMTSTileSource
from bokeh.models.widgets import Slider,DateSlider
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2bbe1060-db4d-4c4c-b7a3-29948601c367">Loading BokehJS ...</span>
#     </div>

# %%
# from https://bokeh.pydata.org/en/latest/docs/gallery/iris.html
from bokeh.plotting import figure, show, output_file
from bokeh.sampledata.iris import flowers

colormap = {'setosa': 'red', 'versicolor': 'green', 'virginica': 'blue'}
colors = [colormap[x] for x in flowers['species']]

p = figure(title = "Iris Morphology")
p.xaxis.axis_label = 'Petal Length'
p.yaxis.axis_label = 'Petal Width'

p.circle(flowers["petal_length"], flowers["petal_width"],
         color=colors, fill_alpha=0.2, size=10)

output_file("iris.html", title="iris.py example")

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="682c8737-a0c8-4202-ab46-7441d93ebeec"></div>
# </div>

# %%
# from https://bokeh.pydata.org/en/latest/docs/gallery/bar_colors.html a
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure

output_file("bar_colors.html")

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]

source = ColumnDataSource(data=dict(fruits=fruits, counts=counts, color=Spectral6))

p = figure(x_range=fruits, y_range=(0,9), plot_height=350, title="Fruit Counts",
           toolbar_location=None, tools="")

p.vbar(x='fruits', top='counts', width=0.9, color='color', legend="fruits", source=source)

p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="9fb5f8e3-66fb-4fca-900a-af61fb7b58a5"></div>
# </div>
